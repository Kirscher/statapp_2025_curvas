# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 34.5 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 20.6 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 26.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 13.8 MB/s eta 0:00:00a 0:00:01
# ...

# %%
# !git clone https://github.com/kck278/stl-to-voxel.git

# !cd stl-to-voxel

# !pip install .
# Out:
# fatal: destination path 'stl-to-voxel' already exists and is not an empty directory.
# Processing /home/onyxia/statapp_2025_curvas/values
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached absl_py-1.4.0-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached aiohttp-3.8.4.tar.gz (7.3 MB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached albumentations-1.3.0-py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached async_timeout-4.0.2-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached attrs-22.2.0-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached batchgenerators-0.25.tar.gz (61 kB)
#   Preparing metadata (setup.py) ... done
# ...

# %%
# !python /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/dataset_generation_benchmark.py --base_save_path /home/onyxia/statapp_2025_curvas/values/data_tests --dataset_name Case_2
# Out:
# The dataset name that you specified does not have config files. Provide a dataset name that in listed in the config directory!

# %%
# !pip install -r /home/onyxia/statapp_2025_curvas/values/requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 19.1 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 53.6 MB/s eta 0:00:0000:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 840.9/840.9 kB 44.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.4/22.4 MB 44.8 MB/s eta 0:00:0000:0100:01
# ...

# %%
# !git clone https://github.com/kck278/stl-to-voxel.git
# !cd stl-to-voxel && pip install .
# Out:
# Cloning into 'stl-to-voxel'...
# remote: Enumerating objects: 769, done.
# remote: Counting objects: 100% (266/266), done.
# remote: Compressing objects: 100% (67/67), done.
# remote: Total 769 (delta 221), reused 199 (delta 199), pack-reused 503 (from 1)
# Receiving objects: 100% (769/769), 11.34 MiB | 19.65 MiB/s, done.
# Resolving deltas: 100% (451/451), done.
# Processing /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/stl-to-voxel
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 39.1 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 20.7 MB/s eta 0:00:00
# ...
#   Created wheel for stl-to-voxel: filename=stl_to_voxel-0.9.1-py3-none-any.whl size=9242 sha256=0702ea575cb5d4876705f7c8c4f3d48d23921f7c1dce7f599a7026254dde1663
# ...

# %%
#forsomereasonnotinstalled
# !pip install scipy
# !pip install SimpleITK
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.2/40.2 MB 66.1 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.3/52.3 MB 68.4 MB/s eta 0:00:00:00:0100:01
# ...

# %%
# !python /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/dataset_generation_benchmark.py --base_save_path /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/data_tests --dataset_name Case_1
# Out:
# Processing layer 0/24
# Processing layer 1/24
# Processing layer 2/24
# Processing layer 3/24
# Processing layer 4/24
# Processing layer 5/24
# Processing layer 6/24
# Processing layer 7/24
# Processing layer 8/24
# Processing layer 9/24
# Processing layer 10/24
# Processing layer 11/24
# Processing layer 12/24
# Processing layer 13/24
# Processing layer 14/24
# Processing layer 15/24
# Processing layer 16/24
# Processing layer 17/24
# Processing layer 18/24
# Processing layer 19/24
# Processing layer 20/24
# Processing layer 21/24
# Processing layer 22/24
# Processing layer 0/26
# Processing layer 1/26
# Processing layer 2/26
# Processing layer 3/26
# Processing layer 4/26
# Processing layer 5/26
# Processing layer 6/26
# Processing layer 7/26
# Processing layer 8/26
# Processing layer 9/26
# Processing layer 10/26
# Processing layer 11/26
# Processing layer 12/26
# Processing layer 13/26
# Processing layer 14/26
# Processing layer 15/26
# Processing layer 16/26
# ...

# %%
# !pip install batchgenerators
# !pip install medpy
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached linecache2-1.0.0-py2.py3-none-any.whl.metadata (1000 bytes)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.7/12.7 MB 65.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.0/15.0 MB 83.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 89.4 MB/s eta 0:00:00
# ...
#   Created wheel for batchgenerators: filename=batchgenerators-0.25.1-py3-none-any.whl size=93131 sha256=fcdb916f7c4008e96111948961400709327ba5bfc4d9ee41eaaa0564e69a0d53
#   Stored in directory: /home/onyxia/.cache/pip/wheels/28/21/2b/7b25080f9f5847e6c3162b89d859d7cec9f3093158e56bd008
# Successfully built batchgenerators
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for medpy: filename=MedPy-0.5.2-py3-none-any.whl size=224775 sha256=1c58f640f1d3eb410979fdefae92019bfa2fa3637b9047f34f6e8a7e677a1c8e
#   Stored in directory: /home/onyxia/.cache/pip/wheels/89/5a/f8/b3def53b9c2133d2f8698ea2173bb5df63bd8e761ce8e9aec9
# ...

# %%
# !cd ..

# !python /home/onyxia/statapp_2025_curvas/values/datasets/preprocess_datasets_3d.py -d /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/data_tests/Case_1 -r 3 -i imagesTr imagesTs -l labelsTr labelsTs --dataset toy

# %%
# !pip install pytorch_lightning
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.3/819.3 kB 87.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 767.5/767.5 kB 37.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 927.3/927.3 kB 81.4 MB/s eta 0:00:00
# ...

# %%
# !python create_splits.py -d /home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation/data_tests/Case_1
# Out:
# Seed set to 123

# %%
# !pip install hydra-core
# Out:
# ...
#   Using cached hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Using cached antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144591 sha256=bcf84cbdbe7cfcb9ba171a538eab5a50b2ac0aea1ff00652bd9e1600883aa0d3
#   Stored in directory: /home/onyxia/.cache/pip/wheels/1f/be/48/13754633f1d08d1fbfc60d5e80ae1e5d7329500477685286cd
# Successfully built antlr4-python3-runtime
# ...

# %%
# !pip install pytorch-lightning==1.9.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.8/825.8 kB 31.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.5.0.post0
#     Uninstalling pytorch-lightning-2.5.0.post0:
#       Successfully uninstalled pytorch-lightning-2.5.0.post0
# ...

# %%
# !pip install tensorboard
# !pip install tensorboardX

# %%
# !USER="your_username" python /home/onyxia/statapp_2025_curvas/values/uncertainty_modeling/main.py
# Out:
# /home/onyxia/statapp_2025_curvas/values/uncertainty_modeling/main.py:33: UserWarning:
# The version_base parameter is not specified.
# Please specify a compatability version level, or None.
# Will assume defaults for version 1.1
#   @hydra.main(config_path="configs", config_name="softmax_config")
# /opt/conda/lib/python3.12/site-packages/hydra/_internal/defaults_list.py:251: UserWarning: In 'softmax_config': Defaults list is missing `_self_`. See https://hydra.cc/docs/1.2/upgrades/1.0_to_1.1/default_composition_order for more information
#   warnings.warn(msg, UserWarning)
# /opt/conda/lib/python3.12/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# SETTING GLOBAL SEED TO 123
# Global seed set to 123
# ...

# %%
import os
#os.chdir('/home/onyxia/statapp_2025_curvas/values/datasets/toy_data_generation')
os.chdir('/home/onyxia/statapp_2025_curvas/values')
print(os.getcwd())
# Out:
# /home/onyxia/statapp_2025_curvas/values
